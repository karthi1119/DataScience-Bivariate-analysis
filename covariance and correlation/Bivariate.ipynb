# %%
import pandas as pd

# %%
dataset=pd.read_csv("Preplacement.csv")

# %%
dataset
# Out:
#      Unnamed: 0  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0             0      1      M  67.00   Others  91.00   Others  Commerce
# 1             1      2      M  79.33  Central  78.33   Others   Science
# 2             2      3      M  65.00  Central  68.00  Central      Arts
# 3             3      4      M  56.00  Central  52.00  Central   Science
# 4             4      5      M  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210         210    211      M  80.60   Others  82.00   Others  Commerce
# 211         211    212      M  58.00   Others  60.00   Others   Science
# 212         212    213      M  67.00   Others  67.00   Others  Commerce
# 213         213    214      F  74.00   Others  66.00   Others  Commerce
# 214         214    215      M  62.00  Central  58.00   Others   Science
#
#      degree_p   degree_t workex  etest_p specialisation  mba_p      status  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0        0
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='object'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['Unnamed: 0',
#  'sl_no',
#  'ssc_p',
#  'hsc_p',
#  'degree_p',
#  'etest_p',
#  'mba_p',
#  'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset[quan].cov()
# Out:
#               Unnamed: 0         sl_no          ssc_p          hsc_p  \
# Unnamed: 0   3870.000000   3870.000000     -52.641355     -58.106028
# sl_no        3870.000000   3870.000000     -52.641355     -58.106028
# ssc_p         -52.641355    -52.641355     117.228377      60.348373
# hsc_p         -58.106028    -58.106028      60.348373     118.755706
# degree_p      -40.413645    -40.413645      42.897137      34.819820
# etest_p        52.556168     52.556168      37.659225      35.461678
# mba_p           8.102336      8.102336      24.535952      22.555846
# salary      24490.654206  24490.654206  901754.893936  763359.777657
#
#                  degree_p        etest_p          mba_p        salary
# Unnamed: 0     -40.413645      52.556168       8.102336  2.449065e+04
# sl_no          -40.413645      52.556168       8.102336  2.449065e+04
# ssc_p           42.897137      37.659225      24.535952  9.017549e+05
# ...

# %%
#The covarience between degree_p and etest_p is 21.929469. so this is positive covarience
#The covarience between etest_p and mba_p is 16.886973. so this is positive covarience

# %%
dataset[quan].corr()
# Out:
#             Unnamed: 0     sl_no     ssc_p     hsc_p  degree_p   etest_p  \
# Unnamed: 0    1.000000  1.000000 -0.078155 -0.085711 -0.088281  0.063636
# sl_no         1.000000  1.000000 -0.078155 -0.085711 -0.088281  0.063636
# ssc_p        -0.078155 -0.078155  1.000000  0.511472  0.538404  0.261993
# hsc_p        -0.085711 -0.085711  0.511472  1.000000  0.434206  0.245113
# degree_p     -0.088281 -0.088281  0.538404  0.434206  1.000000  0.224470
# etest_p       0.063636  0.063636  0.261993  0.245113  0.224470  1.000000
# mba_p         0.022327  0.022327  0.388478  0.354823  0.402364  0.218055
# salary        0.002543  0.002543  0.538090  0.452569  0.408371  0.186988
#
#                mba_p    salary
# Unnamed: 0  0.022327  0.002543
# sl_no       0.022327  0.002543
# ssc_p       0.388478  0.538090
# hsc_p       0.354823  0.452569
# degree_p    0.402364  0.408371
# etest_p     0.218055  0.186988
# mba_p       1.000000  0.139823
# salary      0.139823  1.000000

# %%
# The correlation between mba_p and salary is 0.139823 so this is positive correlation. Here the mba_p is increases the salary also increase.
